# %%
## import packages

import pandas as pd
import numpy as np
from scipy import stats

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('FCC_US_commentstext_datefreq.csv',encoding ='latin-1' )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (5,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [raw]
# df.head(2)

# %%
time_df = df[['id','date_test']]

# %%
time_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2339765 entries, 0 to 2339764
# Data columns (total 2 columns):
# id           object
# date_test    object
# dtypes: object(2)
# memory usage: 35.7+ MB

# %%
#distribute time
sns.distplot(time_df['date_test'].dropna(),kde=False)

# %%
count_series = time_df['date_test'].value_counts()

# %%
count_series.head(30)
# Out:
# 2017-07-17 20:53:08    129286
# 2017-07-17 20:39:21     90679
# 2017-07-17 21:07:07     67025
# 2017-07-17 21:02:51     66852
# 2017-07-12 09:18:33     49055
# 2017-07-12 09:23:15     49054
# 2017-07-12 09:24:23     49034
# 2017-07-12 09:20:55     49024
# 2017-07-12 09:22:17     48989
# 2017-07-12 09:19:40     48980
# 2017-07-17 23:01:02     40426
# 2017-07-12 09:25:18     37314
# 2017-07-14 18:26:53     28512
# 2017-07-12 09:26:18     27512
# 2017-07-12 09:27:16     25690
# 2017-07-12 09:35:46     21238
# 2017-07-12 09:36:26     19521
# 2017-07-12 09:35:04     19442
# 2017-07-12 09:27:43     18678
# 2017-07-17 23:16:41     14947
# 2017-07-14 19:54:58     14671
# 2017-07-17 14:33:14     13433
# 2017-07-12 12:57:27     12335
# 2017-07-17 20:04:55     12237
# 2017-07-12 12:57:24     10257
# 2017-07-12 12:57:17     10012
# 2017-07-13 22:57:47      9585
# 2017-07-12 09:28:04      7889
# 2017-07-16 02:12:26      5997
# 2017-07-12 13:03:31      5375
# Name: date_test, dtype: int64

# %%
counted_time = pd.DataFrame(counted_time)

# %%
counted_time = counted_time.sort_index(axis=1)

# %%
counted_time.head()
# Out:
#                      date_test
# 2017-07-11 15:53:55         12
# 2017-07-11 15:53:56         15
# 2017-07-11 15:53:57         14
# 2017-07-11 15:53:58         17
# 2017-07-11 15:53:59         14

# %%
counted_time.tail()
# Out:
#                      date_test
# 2017-08-16 14:57:42          1
# 2017-08-16 15:01:53          1
# 2017-08-16 15:24:52          1
# 2017-08-16 15:27:41          1
# 2017-08-16 15:33:44          1

# %%
counted_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 400856 entries, 2017-07-11 15:53:55 to 2017-08-16 15:33:44
# Data columns (total 1 columns):
# date_test    400856 non-null int64
# dtypes: int64(1)
# memory usage: 6.1+ MB

# %%
sample_dates = counted_time[388000:390000]

# %%
sample_dates.date_test.plot(x_compat=True, logy=True, figsize=(15,15))

# %%
counted_time.date_test.plot(x_compat=True, figsize=(15,15))

# %%
counted_time.date_test.plot(x_compat=True,logy=True, figsize=(15,15))
